# %%
import numpy as np

# %%
import pandas as pd

# %%
#show plots in notebook
# %matplotlib inline

# %%
import pylab as P

# %%
df = pd.read_csv('../../data/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Age'].hist()

# %%
P.scatter(df['Age'], df['Survived'])
P.xlabel('Age')
P.ylabel('Survived')

# %%
# Recode variables
df['Gender'] = df['Sex'].map( {'female':0 ,'male':1} ).astype(int)
df['Embarked_class'] = df['Embarked'].map( {'C':0, 'Q':1, 'S':2})

# %%
P.scatter(df['Gender'], df['Survived'])
P.xlabel('Gender')
P.ylabel('Survived')

# %%
    median_ages = np.zeros((2,3))
    for i in range(0,2):
        for j in range(0,3):
            median_ages[i,j] = df[ (df['Gender'] == i) & (df['Pclass']==j+1)]['Age'].dropna().median()
            
    df['AgeFill'] = df['Age']
    
    for i in range(0,2):
        for j in range(0,3) :
            df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1), 'AgeFill'] = median_ages[i,j]

    df['AgeIsNull'] = pd.isnull(df.Age).astype(int)

# %%
df[ df['Survived']==1 ]['Age'].hist(bins=20)

# %%
df[ df['Survived']==0 ]['Age'].hist(bins=20)

# %%
df[ df['Survived']==1 ]['Pclass'].hist()

# %%
df[ df['Survived']==0 ]['Pclass'].hist()

# %%
df[ df['Pclass']==3 ]['Survived'].hist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 16 columns):
# PassengerId       891 non-null int64
# Survived          891 non-null int64
# Pclass            891 non-null int64
# Name              891 non-null object
# Sex               891 non-null object
# Age               714 non-null float64
# SibSp             891 non-null int64
# Parch             891 non-null int64
# Ticket            891 non-null object
# Fare              891 non-null float64
# Cabin             204 non-null object
# Embarked          889 non-null object
# Gender            891 non-null int64
# Embarked_class    889 non-null float64
# AgeFill           891 non-null float64
# AgeIsNull         891 non-null int64
# dtypes: float64(4), int64(7), object(5)

# %%
fare_ceiling = 40

#the modify the data in the Fare column to = 39, if greater or equal to ceiliing
df['Fare_bin'] = df['Fare']
#df[ df['Fare_bin'] >= fare_ceiling  ]['Fare_bin'] = fare_ceiling - 1.0    
    
fare_bracket_size = 10
number_of_price_brackets = fare_ceiling / fare_bracket_size
# Out:
# -c:5: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
df['Fare_bin'].describe()
# Out:
# count    891.000000
# mean      19.635427
# std       12.654171
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max       39.687500
# dtype: float64

# %%
df['Fare_bin'].hist()

# %%
print(( df[df['Survived']==0]['Survived'].count()*1.0)  )
# Out:
# 486.0

# %%
df['Survived'].hist()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Title'] = df['Name'].str.split(',').str.get(1)
df['Title'] = df['Title'].map(str.strip)
df['Title'] = df['Title'].str.split(' ').str.get(0)
df['Title'] = df['Title'].map(str.strip)

# %%
df[['Title', 'Name']]
# Out:
#        Title                                               Name
# 0        Mr.                            Braund, Mr. Owen Harris
# 1       Mrs.  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      Miss.                             Heikkinen, Miss. Laina
# 3       Mrs.       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4        Mr.                           Allen, Mr. William Henry
# 5        Mr.                                   Moran, Mr. James
# 6        Mr.                            McCarthy, Mr. Timothy J
# 7    Master.                     Palsson, Master. Gosta Leonard
# 8       Mrs.  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9       Mrs.                Nasser, Mrs. Nicholas (Adele Achem)
# 10     Miss.                    Sandstrom, Miss. Marguerite Rut
# 11     Miss.                           Bonnell, Miss. Elizabeth
# 12       Mr.                     Saundercock, Mr. William Henry
# 13       Mr.                        Andersson, Mr. Anders Johan
# ...

# %%
df['Title'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# Capt.          1
# Sir.           1
# the            1
# Don.           1
# Jonkheer.      1
# Ms.            1
# Mme.           1
# Lady.          1
# dtype: int64

# %%
df['Title_Code'] = pd.Categorical.from_array(df.Title).labels
#df.head(15)
ageIsMissing_df = df[ df['AgeIsNull']==1]
ageIsMissing_df[ ['Pclass', 'Name', 'Title', 'Age', 'AgeFill'] ] .head(10)
# Out:
#     Pclass                                            Name  Title  Age  \
# 5        3                                Moran, Mr. James    Mr.  NaN
# 17       2                    Williams, Mr. Charles Eugene    Mr.  NaN
# 19       3                         Masselmani, Mrs. Fatima   Mrs.  NaN
# 26       3                         Emir, Mr. Farred Chehab    Mr.  NaN
# 28       3                   O'Dwyer, Miss. Ellen "Nellie"  Miss.  NaN
# 29       3                             Todoroff, Mr. Lalio    Mr.  NaN
# 31       1  Spencer, Mrs. William Augustus (Marie Eugenie)   Mrs.  NaN
# 32       3                        Glynn, Miss. Mary Agatha  Miss.  NaN
# 36       3                                Mamee, Mr. Hanna    Mr.  NaN
# 42       3                             Kraeff, Mr. Theodor    Mr.  NaN
#
#     AgeFill
# 5      25.0
# 17     30.0
# 19     21.5
# 26     25.0
# 28     21.5
# 29     25.0
# 31     35.0
# 32     21.5
# 36     25.0
# 42     25.0

# %%
ageIsMissing_df.Title.value_counts()
# Out:
# Mr.        119
# Miss.       36
# Mrs.        17
# Master.      4
# Dr.          1
# dtype: int64

# %%
ageIsMissing_df.groupby(['Pclass' , 'Gender', 'Title']).count()
# Out:
#                        PassengerId  Survived  Name  Sex  Age  SibSp  Parch  \
# Pclass Gender Title
# 1      0      Miss.              1         1     1    1    0      1      1
#               Mrs.               8         8     8    8    0      8      8
#        1      Dr.                1         1     1    1    0      1      1
#               Mr.               20        20    20   20    0     20     20
# 2      0      Miss.              2         2     2    2    0      2      2
#        1      Mr.                9         9     9    9    0      9      9
# 3      0      Miss.             33        33    33   33    0     33     33
#               Mrs.               9         9     9    9    0      9      9
#        1      Master.            4         4     4    4    0      4      4
#               Mr.               90        90    90   90    0     90     90
#
#                        Ticket  Fare  Cabin  Embarked  Fare_bin  \
# Pclass Gender Title
# ...

# %%
median_age_by_title_pclass = df[df['AgeIsNull']==0].groupby(['Pclass' , 'Gender', 'Title_Code'])['Age'].median()

# %%
median_age_by_title_pclass
# Out:
# Pclass  Gender  Title_Code
# 1       0       3             49.0
#                 5             48.0
#                 8             30.0
#                 9             24.0
#                 10            24.0
#                 12            41.5
#                 16            33.0
#         1       0             70.0
#                 1             58.0
#                 2             40.0
#                 3             44.0
#                 4             38.0
#                 6             48.5
#                 7              4.0
#                 11            40.0
#                 15            49.0
# 2       0       8             24.0
#                 12            32.0
#                 13            28.0
#         1       3             38.5
#                 7              1.0
#                 11            31.0
#                 14            46.5
# 3       0       8             18.0
#                 12            31.0
#         1       7              4.0
# ...

# %%
num_types_titles = int(len(df['Title'].value_counts()))
num_types_titles
# Out:
# 17

# %%
medAges = {}
for g in range(0,2):
    for c in range(1,4):
        for t in range(0,num_types_titles +1):
            #print("%d %d %d" % (g,c,t))
            key = str(g) + str(c) + str(t)
            medAges[key] = df[  (df['AgeIsNull']==0) & (df['Gender']==g) & (df['Pclass']==c)  & (df['Title_Code']==t) ]['Age'].median()


print medAges
# Out:
# {'126': nan, '127': 1.0, '010': nan, '011': nan, '012': nan, '013': 49.0, '014': nan, '015': 48.0, '016': nan, '017': nan, '018': 30.0, '019': 24.0, '139': nan, '138': nan, '1317': nan, '1316': nan, '1315': nan, '1314': nan, '1313': nan, '1312': nan, '1311': 26.0, '0313': nan, '120': nan, '024': nan, '122': nan, '123': 38.5, '124': nan, '020': nan, '023': nan, '022': nan, '128': nan, '129': nan, '029': nan, '028': 24.0, '133': nan, '132': nan, '135': nan, '131': nan, '130': nan, '137': 4.0, '136': nan, '0112': 41.5, '0113': nan, '0110': 24.0, '0111': nan, '0116': 33.0, '0117': nan, '0114': nan, '0115': nan, '134': nan, '115': nan, '114': 38.0, '038': 18.0, '039': nan, '111': 58.0, '110': 70.0, '113': 44.0, '112': 40.0, '032': nan, '033': nan, '030': nan, '031': nan, '036': nan, '037': nan, '034': nan, '035': nan, '0211': nan, '0210': nan, '0213': 28.0, '0212': 32.0, '0215': nan, '0214': nan, '0217': nan, '0216': nan, '1212': nan, '1213': nan, '1210': nan, '1211': 31.0, '1216': nan, '
# ...

# %%
df['newAgeFill'] = df['Age']

import math

for g in range(0,2):
    for c in range(1,4):
        for t in range(0,num_types_titles +1):
            key = str(g) + str(c) + str(t)
            if math.isnan(medAges.get(key))==False:
                print ("writing to ",df[  (df['AgeIsNull']==1) & (df['Gender']==g) & (df['Pclass']==c)  & (df['Title_Code']==t) ]['PassengerId'].count(), " records" )
                df.loc[  (df['AgeIsNull']==1) & (df['Gender']==g) & (df['Pclass']==c)  & (df['Title_Code']==t) ,'newAgeFill'] = medAges.get(key)

df.info()
# Out:
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 1, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 8, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 2, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 33, ' records')
# ('writing to ', 9, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 1, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 20, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 9, ' records')
# ('writing to ', 0, ' records')
# ('writing to ', 4, ' records')
# ('writing to ', 90, ' records')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# ...

# %%
df['newAgeFill'].hist()

# %%
df['Age'].hist()

# %%
df['AgeFill'].hist(bins=30)
df['newAgeFill'].hist(bins=30)

# %%
df['newAgeFill'].describe()
# Out:
# count    891.000000
# mean      29.143850
# std       13.496074
# min        0.420000
# 25%       21.000000
# 50%       26.000000
# 75%       36.750000
# max       80.000000
# dtype: float64

# %%
df['AgeFill'].describe()
# Out:
# count    891.000000
# mean      29.112424
# std       13.304424
# min        0.420000
# 25%       21.500000
# 50%       26.000000
# 75%       36.000000
# max       80.000000
# dtype: float64

# %%
df['newAgeFill'].median()
# Out:
# 26.0

# %%
df['AgeFill'].median()
# Out:
# 26.0

# %%
y_agefill,binEdges_ageFill=np.histogram(df['AgeFill'],bins=100)
bincenters = 0.5*(binEdges_ageFill[1:]+binEdges_ageFill[:-1])
P.plot(bincenters,y_agefill,'-')

y_newagefill,binEdges_newageFill=np.histogram(df['newAgeFill'],bins=100)
new_bincenters = 0.5*(binEdges_newageFill[1:]+binEdges_newageFill[:-1])
P.plot(new_bincenters,y_newagefill,'-')
